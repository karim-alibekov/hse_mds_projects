# %% [markdown]
# # Final Game "ChatRPG" by Karim Alibekov
#
# ### Game has nothing to do with ChatGPT, it is just humour, since genre is RPG and realisation is through text quest! :)

# %% [markdown]
# # Description & Concept

# %% [markdown]
# **TO WIN THE GAME YOU NEED TO DEFEAT ALL THREE BOSSES IN THREE WORLDS**
#
#     – YOU CAN CHOOSE HERO CLASS BETWEEN WARRIOR, DRUID AND MAGE, EACH OF THEM HAS ITS OWN UNIQUE WEAPONS AND PASSIVE ABILITIES
#
#     – YOU CAN ALSO BUY WEAPONS, ARMOUR AND RECRUITING ALLIES
#
#     – EACH OF THE ITEMS IN THE MERCHANT SHOP CAN BE UPGRADED TO BETTER ONE, THERE EXISTS 3 LEVELS OF EACH ITEM CATEGORY
#
#     – YOU CAN ENCOUNTER MYSTERIOUS RIDDLER, WHO WANTS TO PLAY AND TEST YOUR INTELLIGENCE OR LUCK
#
#     – YOU CAN ALSO ENCOUNTER UNIQUE MONSTERS AND UNIQUE BOSSES IN THEIR WORLDS
#
# **GOOD LUCK WITH EXPLORING THE WORLD OF THE GAME!**

# %%
# WORLDS

MAGIC_VALLEY_WORLD = 'Magic Valley'
MIRROR_MAZE_WORLD = 'Mirror Maze'
TOWER_OF_ILLUSIONS_WORLD = 'Tower of Illusions'

worlds = [MAGIC_VALLEY_WORLD, MIRROR_MAZE_WORLD, TOWER_OF_ILLUSIONS_WORLD]

merchant_shop = {'Northern Wolf': {'gold': 500, 'health': 500, 'power': 100},
                 
                 'One-Armed Dwarf': {'gold': 700, 'health': 700, 'power': 200},
                 
                 'Enchanted Elf': {'gold': 1000, 'health': 800, 'power': 300},
                 
                 'Bronze Armour': {'gold': 500, 'armour': 200},
                 
                 'Silver Armour': {'gold': 700, 'armour': 300},
                 
                 'Platinum Armour': {'gold': 1000, 'armour': 400},
                
                 'Steel Axe': {'gold': 500, 'power': 500},
                
                 'King Axe': {'gold': 700, 'power': 500},
                
                 'Double-Edged Poisoned Axe': {'gold': 1000, 'power': 500},
                
                 'Bear-Claw Dagger': {'gold': 500, 'power': 500},
                
                 'Elven Sword': {'gold': 700, 'power': 500},
                
                 'Lunar Eclipse Stick': {'gold': 1000, 'power': 500},
                 
                 'Freezing Bow': {'gold': 500, 'power': 500},
                
                 'Cursed Sword': {'gold': 700, 'power': 500},
                
                 'Hellfire Lasso': {'gold': 1000, 'power': 500}}

# BOSSES

bosses = {'Arcane Overlord': {'health': 500, 'power': 50, 'armour': 100, 'world': MAGIC_VALLEY_WORLD, 
                              'gold_prize': 1000},
          
          'Reflection Master': {'health': 500, 'power': 50, 'armour': 100, 'world': MIRROR_MAZE_WORLD, 
                               'gold_prize': 1000},
          
          'Spectral Conjurer': {'health': 500, 'power': 50, 'armour': 100, 'world': TOWER_OF_ILLUSIONS_WORLD,
                               'gold_prize': 1000}}

# MONSTERS

monsters = {'Crazy Magician': {'health': 200, 'power': 40, 'armour': 20, 'world': MAGIC_VALLEY_WORLD,
                              'gold_prize': 500},
            
            'Glassy Warlock': {'health': 200, 'power': 40, 'armour': 20, 'world': MIRROR_MAZE_WORLD,
                              'gold_prize': 500},
            
            'Hide-n-Seeker': {'health': 200, 'power': 40, 'armour': 20, 'world': TOWER_OF_ILLUSIONS_WORLD,
                             'gold_prize': 500}}

riddles = []

explored_worlds = []

# CREATING A HERO

heroes = {'warrior': {'health': 570, 'power': 50, 'armour': 0, 'weapons': ['wooden sword'], 'armours': [], 'gold': 0, 'allies': [], 'allies_health': 0, 'allies_power': 0, 'passive abilities': '10% more damage during fight'},
        'druid': {'health': 600, 'power': 40, 'armour': 0, 'weapons': ['moon dagger'], 'armours': [], 'gold': 0, 'allies': [], 'allies_health': 0, 'allies_power': 0, 'passive abilities': 'allies have 7% more damage and health during fight'},
        'mage': {'health': 540, 'power': 60, 'armour': 0, 'weapons': ['wooden ward'], 'armours': [], 'gold': 0, 'allies': [], 'allies_health': 0, 'allies_power': 0, 'passive abilities': '10% more health during fight'}}

# CHOOSE HERO CLASS

def Create_Hero_1():
    
    global chosen_hero
    global hero_class
    
    while True:

        hero_class = input(f'Choose a hero class between {", ".join(heroes.keys())}: ')

        if hero_class not in list(heroes.keys()):
            print("Invalid hero class! Enter class in lowercase and check the spelling!")
            continue
        else:
            print('Your hero class is: {}'.format(hero_class))
            chosen_hero = heroes[hero_class]
            break
            
# CHOOSE HERO NAME
            
def Create_Hero_2():
    
    global hero_name

    while True:
        
        hero_name = input('Choose a hero name: ')
        
        if hero_name.isalpha():
            print('Your hero name is: {}'.format(hero_name))
            chosen_hero['name'] = hero_name
            break
        else:
            print("Invalid hero name! Please enter a valid name only consisting of letters.")
            
# HERO STATS
        
def Hero_Stats(): 
    return chosen_hero

# SELECTION OF WORLD
    
def Choose_World():
    
    global chosen_world
    
    while True:

        worlds_numbered = {
            '1': MAGIC_VALLEY_WORLD,
            '2': MIRROR_MAZE_WORLD,
            '3': TOWER_OF_ILLUSIONS_WORLD,
        }
        worlds_numbered_for_print = '\n'.join([f'{number} - {world}' for number, world in worlds_numbered.items()])
        number = input(f'Choose the world you want to explore (enter number): {worlds_numbered_for_print}: ')

        chosen_world = worlds_numbered[number]

        if number not in worlds_numbered:
            print("Chosen world does not exist! Enter the valid name")
            continue
        elif chosen_world in explored_worlds:
            print("You've already explored this world, choose another one!")
            continue
        elif number in worlds_numbered and chosen_world not in explored_worlds:
            explored_worlds.append(chosen_world)
            break
        else:
            continue
                    
# MONSTER STATS

def monsters_stats(monster):
    damage = monster['power']
    health = monster['health'] + monster['armour']
    return damage, health

# HERO STATS

def hero_stats(hero_class):
    if hero_class == 'warrior':
        damage = chosen_hero['power'] * 1.1 
        health = chosen_hero['health'] + chosen_hero['armour']
    elif hero_class == 'druid':
        damage = chosen_hero['power']
        health = chosen_hero['health'] + chosen_hero['armour']
    elif hero_class == 'mage':
        damage = chosen_hero['power']
        health = (chosen_hero['health'] + chosen_hero['armour']) * 1.1
    return damage, health

# ALLIES STATS

def allies_stats(hero_class):
    if hero_class == 'warrior':
        damage = chosen_hero['allies_power']
        health = chosen_hero['allies_health']
    elif hero_class == 'druid':
        damage = chosen_hero['allies_power'] * 1.07
        health = chosen_hero['allies_health'] * 1.07
    elif hero_class == 'mage':
        damage = chosen_hero['allies_power']
        health = chosen_hero['allies_health']
    return damage, health

# FIGHT WITH MONSTER SIMULATION

def Fight_Monster():
    
    print("You've encountered your first monster! Be brave and show them what you are made of!")
        
    if chosen_world == MAGIC_VALLEY_WORLD:
             
        current_monster = monsters['Crazy Magician']
        monster_damage, monster_health = monsters_stats(current_monster)

        player_damage, player_health = hero_stats(hero_class)
            
        
        while True:

            # player always attacks first
            
            if player_health > 0 and monster_health <= 0:
                print('CONGRATULATIONS, YOU WON YOUR FIRST BATTLE!')
                print('YOU EARNED {}'.format(monsters['Crazy Magician']['gold_prize']), 'gold')
                chosen_hero['gold'] += monsters['Crazy Magician']['gold_prize']
                break
            
            elif player_health <= 0 and monster_health > 0:
                print('YOU ARE DEAD')
                break
            
            monster_health -= player_damage
            print("{} dealed".format(hero_name), player_damage, "damage to Crazy Magician")
            print("Crazy Magician health is: ", monster_health)
            
            player_health -= monster_damage
            print("Crazy Magician dealed", monster_damage, "damage to {}".format(hero_name))
            print("{} health is: ".format(hero_name), player_health)
  
            
    elif chosen_world == MIRROR_MAZE_WORLD:
        
        current_monster = monsters['Glassy Warlock']
        monster_damage, monster_health = monsters_stats(current_monster)

        player_damage, player_health = hero_stats(hero_class)
            
        
        while True:

            # player always attacks first
            
            if player_health > 0 and monster_health <= 0:
                print('CONGRATULATIONS, YOU WON YOUR FIRST BATTLE!')
                print('YOU EARNED {}'.format(monsters['Glassy Warlock']['gold_prize']), 'gold')
                chosen_hero['gold'] += monsters['Glassy Warlock']['gold_prize']
                break
            
            elif player_health <= 0 and monster_health > 0:
                print('YOU ARE DEAD')
                break
            
            monster_health -= player_damage
            print("{} dealed".format(hero_name), player_damage, "damage to Glassy Warlock")
            print("Glassy Warlock health is: ", monster_health)
            
            player_health -= monster_damage
            print("Glassy Warlock dealed", monster_damage, "damage to {}".format(hero_name))
            print("{} health is: ".format(hero_name), player_health)
    
    elif chosen_world == TOWER_OF_ILLUSIONS_WORLD:
        
        current_monster = monsters['Hide-n-Seeker']
        monster_damage, monster_health = monsters_stats(current_monster)

        player_damage, player_health = hero_stats(hero_class)
            
        
        while True:

            # player always attacks first
            
            if player_health > 0 and monster_health <= 0:
                print('CONGRATULATIONS, YOU WON YOUR FIRST BATTLE!')
                print('YOU EARNED {}'.format(monsters['Hide-n-Seeker']['gold_prize']), 'gold')
                chosen_hero['gold'] += monsters['Hide-n-Seeker']['gold_prize']
                break
            
            elif player_health <= 0 and monster_health > 0:
                print('YOU ARE DEAD')
                break
            
            monster_health -= player_damage
            print("{} dealed".format(hero_name), player_damage, "damage to Hide-n-Seeker")
            print("Hide-n-Seeker health is: ", monster_health)
            
            player_health -= monster_damage
            print("Hide-n-Seeker dealed", monster_damage, "damage to {}".format(hero_name))
            print("{} health is: ".format(hero_name), player_health)
        
# STEP 4: MERCHANT SHOPPING: WEAPONS, ARMOURS, ALLIES

def Merchant_Shopping():
    
    print('Merchant: Welcome Stranger! I have best weapons, solid armour and you can recruit allies here, just choose between weapon, armour, ally')
    
    global exit
    
    while exit.lower() != "no":

        items = ['weapon', 'armour', 'ally']
            
        exit = input('Merchant: Do you want to buy something? Enter yes or no: ')

        if exit.lower() == "yes":
                
            print('Your current balance is: {}'.format(chosen_hero['gold']))
            item = input('What are you buying? Choose between weapon, armour or ally: ')

            if item not in items:

                print("Chosen item does not exist! Enter the valid item name!")
                continue

            elif item in items:
                
                # WARRIOR | WEAPON

                if hero_class == 'warrior' and item == 'weapon':

                    print('Merchant: You can choose between', list(merchant_shop.keys())[6], '|', list(merchant_shop.keys())[7], '|', list(merchant_shop.keys())[8])
                    print('Weapon:', list(merchant_shop.keys())[6], '|', 'Price:', merchant_shop['Steel Axe']['gold'])
                    print('Weapon:', list(merchant_shop.keys())[7], '|', 'Price:', merchant_shop['King Axe']['gold'])
                    print('Weapon:', list(merchant_shop.keys())[8], '|', 'Price:', merchant_shop['Double-Edged Poisoned Axe']['gold'])
                    print('Your current balance is: {}'.format(chosen_hero['gold']))

                    while True:

                        weapon_chosen = input('I choose: ')

                        if weapon_chosen not in [list(merchant_shop.keys())[6], list(merchant_shop.keys())[7], list(merchant_shop.keys())[8]]:
                            print("Chosen weapon does not exist! Enter the valid weapon name!")
                            continue
                            
                        # STEEL AXE

                        elif weapon_chosen in [list(merchant_shop.keys())[6], list(merchant_shop.keys())[7], list(merchant_shop.keys())[8]] and weapon_chosen == list(merchant_shop.keys())[6] and chosen_hero['gold'] >= merchant_shop['Steel Axe']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Steel Axe']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['weapons'].append(list(merchant_shop.keys())[6])
                            chosen_hero['power'] += merchant_shop['Steel Axe']['power']

                            break
                            
                        # KING AXE
                            
                        elif weapon_chosen in [list(merchant_shop.keys())[6], list(merchant_shop.keys())[7], list(merchant_shop.keys())[8]] and weapon_chosen == list(merchant_shop.keys())[7] and chosen_hero['gold'] >= merchant_shop['King Axe']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['King Axe']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['weapons'].append(list(merchant_shop.keys())[7])
                            chosen_hero['power'] += merchant_shop['King Axe']['power']

                            break
                            
                        # DOUBLE-EDGED POISONED AXE
                            
                        elif weapon_chosen in [list(merchant_shop.keys())[6], list(merchant_shop.keys())[7], list(merchant_shop.keys())[8]] and weapon_chosen == list(merchant_shop.keys())[8] and chosen_hero['gold'] >= merchant_shop['Double-Edged Poisoned Axe']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Double-Edged Poisoned Axe']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['weapons'].append(list(merchant_shop.keys())[8])
                            chosen_hero['power'] += merchant_shop['Double-Edged Poisoned Axe']['power']

                            break
                                
                        else:
                            print('You do not have enough money')
                            break
                            
                # WARRIOR | ARMOUR

                elif hero_class == 'warrior' and item == 'armour':

                    print('Merchant: You can choose between', list(merchant_shop.keys())[3], '|', list(merchant_shop.keys())[4], '|', list(merchant_shop.keys())[5])
                    print('Armour:', list(merchant_shop.keys())[3], '|', 'Price:', merchant_shop['Bronze Armour']['gold'])
                    print('Armour:', list(merchant_shop.keys())[4], '|', 'Price:', merchant_shop['Silver Armour']['gold'])
                    print('Armour:', list(merchant_shop.keys())[5], '|', 'Price:', merchant_shop['Platinum Armour']['gold'])
                    print('Your current balance is: {}'.format(chosen_hero['gold']))

                    while True:

                        armour_chosen = input('I choose: ')

                        if armour_chosen not in [list(merchant_shop.keys())[3], list(merchant_shop.keys())[4], list(merchant_shop.keys())[5]]:
                            print("Chosen armour does not exist! Enter the valid armour name!")
                            continue
                            
                        # BRONZE ARMOUR

                        elif armour_chosen in [list(merchant_shop.keys())[3], list(merchant_shop.keys())[4], list(merchant_shop.keys())[5]] and armour_chosen == list(merchant_shop.keys())[3] and chosen_hero['gold'] >= merchant_shop['Bronze Armour']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Bronze Armour']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['armours'].append(list(merchant_shop.keys())[3])
                            chosen_hero['armour'] += merchant_shop['Bronze Armour']['armour']

                            break
                            
                        # SILVER ARMOUR
                            
                        elif armour_chosen in [list(merchant_shop.keys())[3], list(merchant_shop.keys())[4], list(merchant_shop.keys())[5]] and armour_chosen == list(merchant_shop.keys())[4] and chosen_hero['gold'] >= merchant_shop['Silver Armour']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Silver Armour']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['armours'].append(list(merchant_shop.keys())[4])
                            chosen_hero['armour'] += merchant_shop['Silver Armour']['armour']

                            break
                            
                        # PLATINUM ARMOUR
                            
                        elif armour_chosen in [list(merchant_shop.keys())[3], list(merchant_shop.keys())[4], list(merchant_shop.keys())[5]] and armour_chosen == list(merchant_shop.keys())[5] and chosen_hero['gold'] >= merchant_shop['Platinum Armour']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Platinum Armour']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['armours'].append(list(merchant_shop.keys())[5])
                            chosen_hero['armour'] += merchant_shop['Platinum Armour']['armour']

                            break
                                
                        else:
                            print('You do not have enough money')
                            break
                            
                # WARRIOR | ALLY

                elif hero_class == 'warrior' and item == 'ally':

                    print('Merchant: You can choose between', list(merchant_shop.keys())[0], '|', list(merchant_shop.keys())[1], '|', list(merchant_shop.keys())[2])
                    print('Ally:', list(merchant_shop.keys())[0], '|', 'Price:', merchant_shop['Northern Wolf']['gold'])
                    print('Ally:', list(merchant_shop.keys())[1], '|', 'Price:', merchant_shop['One-Armed Dwarf']['gold'])
                    print('Ally:', list(merchant_shop.keys())[2], '|', 'Price:', merchant_shop['Enchanted Elf']['gold'])
                    print('Your current balance is: {}'.format(chosen_hero['gold']))

                    while True:

                        ally_chosen = input('I choose: ')

                        if ally_chosen not in [list(merchant_shop.keys())[0], list(merchant_shop.keys())[1], list(merchant_shop.keys())[2]]:
                            print("Chosen ally does not exist! Enter the valid ally name!")
                            continue
                            
                        # NORTHERN WOLF

                        elif ally_chosen in [list(merchant_shop.keys())[0], list(merchant_shop.keys())[1], list(merchant_shop.keys())[2]] and ally_chosen == list(merchant_shop.keys())[0] and chosen_hero['gold'] >= merchant_shop['Northern Wolf']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Northern Wolf']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['allies'].append(list(merchant_shop.keys())[0])
                            chosen_hero['allies_health'] += merchant_shop['Northern Wolf']['health']
                            chosen_hero['allies_power'] += merchant_shop['Northern Wolf']['power']

                            break
                            
                        # ONE-ARMED DWARF
                            
                        elif ally_chosen in [list(merchant_shop.keys())[0], list(merchant_shop.keys())[1], list(merchant_shop.keys())[2]] and ally_chosen == list(merchant_shop.keys())[1] and chosen_hero['gold'] >= merchant_shop['One-Armed Dwarf']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['One-Armed Dwarf']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['allies'].append(list(merchant_shop.keys())[1])
                            chosen_hero['allies_health'] += merchant_shop['One-Armed Dwarf']['health']
                            chosen_hero['allies_power'] += merchant_shop['One-Armed Dwarf']['power']

                            break
                            
                        # ENCHANTED ELF
                            
                        elif ally_chosen in [list(merchant_shop.keys())[0], list(merchant_shop.keys())[1], list(merchant_shop.keys())[2]] and ally_chosen == list(merchant_shop.keys())[2] and chosen_hero['gold'] >= merchant_shop['Enchanted Elf']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Enchanted Elf']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['allies'].append(list(merchant_shop.keys())[2])
                            chosen_hero['allies_health'] += merchant_shop['Enchanted Elf']['health']
                            chosen_hero['allies_power'] += merchant_shop['Enchanted Elf']['power']

                            break
                                
                        else:
                            print('You do not have enough money')
                            break
                            
                # DRUID | WEAPON

                if hero_class == 'druid' and item == 'weapon':

                    print('Merchant: You can choose between', list(merchant_shop.keys())[9], '|', list(merchant_shop.keys())[10], '|', list(merchant_shop.keys())[11])
                    print('Weapon:', list(merchant_shop.keys())[9], '|', 'Price:', merchant_shop['Bear-Claw Dagger']['gold'])
                    print('Weapon:', list(merchant_shop.keys())[10], '|', 'Price:', merchant_shop['Elven Sword']['gold'])
                    print('Weapon:', list(merchant_shop.keys())[11], '|', 'Price:', merchant_shop['Lunar Eclipse Stick']['gold'])
                    print('Your current balance is: {}'.format(chosen_hero['gold']))

                    while True:

                        weapon_chosen = input('I choose: ')

                        if weapon_chosen not in [list(merchant_shop.keys())[9], list(merchant_shop.keys())[10], list(merchant_shop.keys())[11]]:
                            print("Chosen weapon does not exist! Enter the valid weapon name!")
                            continue
                            
                        # BEAR-CLAW DAGGER

                        elif weapon_chosen in [list(merchant_shop.keys())[9], list(merchant_shop.keys())[10], list(merchant_shop.keys())[11]] and weapon_chosen == list(merchant_shop.keys())[9] and chosen_hero['gold'] >= merchant_shop['Bear-Claw Dagger']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Bear-Claw Dagger']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['weapons'].append(list(merchant_shop.keys())[9])
                            chosen_hero['power'] += merchant_shop['Bear-Claw Dagger']['power']

                            break
                            
                        # Elven Sword
                            
                        elif weapon_chosen in [list(merchant_shop.keys())[9], list(merchant_shop.keys())[10], list(merchant_shop.keys())[11]] and weapon_chosen == list(merchant_shop.keys())[10] and chosen_hero['gold'] >= merchant_shop['Elven Sword']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Elven Sword']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['weapons'].append(list(merchant_shop.keys())[10])
                            chosen_hero['power'] += merchant_shop['Elven Sword']['power']

                            break
                            
                        # Lunar Eclipse Stick
                            
                        elif weapon_chosen in [list(merchant_shop.keys())[9], list(merchant_shop.keys())[10], list(merchant_shop.keys())[11]] and weapon_chosen == list(merchant_shop.keys())[11] and chosen_hero['gold'] >= merchant_shop['Lunar Eclipse Stick']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Lunar Eclipse Stick']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['weapons'].append(list(merchant_shop.keys())[11])
                            chosen_hero['power'] += merchant_shop['Lunar Eclipse Stick']['power']

                            break
                                
                        else:
                            print('You do not have enough money')
                            break
                            
                # DRUID | ARMOUR

                elif hero_class == 'druid' and item == 'armour':

                    print('Merchant: You can choose between', list(merchant_shop.keys())[3], '|', list(merchant_shop.keys())[4], '|', list(merchant_shop.keys())[5])
                    print('Armour:', list(merchant_shop.keys())[3], '|', 'Price:', merchant_shop['Bronze Armour']['gold'])
                    print('Armour:', list(merchant_shop.keys())[4], '|', 'Price:', merchant_shop['Silver Armour']['gold'])
                    print('Armour:', list(merchant_shop.keys())[5], '|', 'Price:', merchant_shop['Platinum Armour']['gold'])
                    print('Your current balance is: {}'.format(chosen_hero['gold']))
                    

                    while True:

                        armour_chosen = input('I choose: ')

                        if armour_chosen not in [list(merchant_shop.keys())[3], list(merchant_shop.keys())[4], list(merchant_shop.keys())[5]]:
                            print("Chosen armour does not exist! Enter the valid armour name!")
                            continue
                            
                        # BRONZE ARMOUR

                        elif armour_chosen in [list(merchant_shop.keys())[3], list(merchant_shop.keys())[4], list(merchant_shop.keys())[5]] and armour_chosen == list(merchant_shop.keys())[3] and chosen_hero['gold'] >= merchant_shop['Bronze Armour']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Bronze Armour']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['armours'].append(list(merchant_shop.keys())[3])
                            chosen_hero['armour'] += merchant_shop['Bronze Armour']['armour']

                            break
                            
                        # SILVER ARMOUR
                            
                        elif armour_chosen in [list(merchant_shop.keys())[3], list(merchant_shop.keys())[4], list(merchant_shop.keys())[5]] and armour_chosen == list(merchant_shop.keys())[4] and chosen_hero['gold'] >= merchant_shop['Silver Armour']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Silver Armour']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['armours'].append(list(merchant_shop.keys())[4])
                            chosen_hero['armour'] += merchant_shop['Silver Armour']['armour']

                            break
                            
                        # PLATINUM ARMOUR
                            
                        elif armour_chosen in [list(merchant_shop.keys())[3], list(merchant_shop.keys())[4], list(merchant_shop.keys())[5]] and armour_chosen == list(merchant_shop.keys())[5] and chosen_hero['gold'] >= merchant_shop['Platinum Armour']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Platinum Armour']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['armours'].append(list(merchant_shop.keys())[5])
                            chosen_hero['armour'] += merchant_shop['Platinum Armour']['armour']

                            break
                                
                        else:
                            print('You do not have enough money')
                            break
                            
                # DRUID | ALLY

                elif hero_class == 'druid' and item == 'ally':

                    print('Merchant: You can choose between', list(merchant_shop.keys())[0], '|', list(merchant_shop.keys())[1], '|', list(merchant_shop.keys())[2])
                    print('Ally:', list(merchant_shop.keys())[0], '|', 'Price:', merchant_shop['Northern Wolf']['gold'])
                    print('Ally:', list(merchant_shop.keys())[1], '|', 'Price:', merchant_shop['One-Armed Dwarf']['gold'])
                    print('Ally:', list(merchant_shop.keys())[2], '|', 'Price:', merchant_shop['Enchanted Elf']['gold'])
                    print('Your current balance is: {}'.format(chosen_hero['gold']))

                    while True:

                        ally_chosen = input('I choose: ')

                        if ally_chosen not in [list(merchant_shop.keys())[0], list(merchant_shop.keys())[1], list(merchant_shop.keys())[2]]:
                            print("Chosen ally does not exist! Enter the valid ally name!")
                            continue
                            
                        # NORTHERN WOLF

                        elif ally_chosen in [list(merchant_shop.keys())[0], list(merchant_shop.keys())[1], list(merchant_shop.keys())[2]] and ally_chosen == list(merchant_shop.keys())[0] and chosen_hero['gold'] >= merchant_shop['Northern Wolf']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Northern Wolf']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['allies'].append(list(merchant_shop.keys())[0])
                            chosen_hero['allies_health'] += merchant_shop['Northern Wolf']['health']
                            chosen_hero['allies_power'] += merchant_shop['Northern Wolf']['power']

                            break
                            
                        # ONE-ARMED DWARF
                            
                        elif ally_chosen in [list(merchant_shop.keys())[0], list(merchant_shop.keys())[1], list(merchant_shop.keys())[2]] and ally_chosen == list(merchant_shop.keys())[1] and chosen_hero['gold'] >= merchant_shop['One-Armed Dwarf']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['One-Armed Dwarf']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['allies'].append(list(merchant_shop.keys())[1])
                            chosen_hero['allies_health'] += merchant_shop['One-Armed Dwarf']['health']
                            chosen_hero['allies_power'] += merchant_shop['One-Armed Dwarf']['power']

                            break
                            
                        # ENCHANTED ELF
                            
                        elif ally_chosen in [list(merchant_shop.keys())[0], list(merchant_shop.keys())[1], list(merchant_shop.keys())[2]] and ally_chosen == list(merchant_shop.keys())[2] and chosen_hero['gold'] >= merchant_shop['Enchanted Elf']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Enchanted Elf']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['allies'].append(list(merchant_shop.keys())[2])
                            chosen_hero['allies_health'] += merchant_shop['Enchanted Elf']['health']
                            chosen_hero['allies_power'] += merchant_shop['Enchanted Elf']['power']

                            break
                                
                        else:
                            print('You do not have enough money')
                            break
                            
                 # MAGE | WEAPON

                if hero_class == 'mage' and item == 'weapon':

                    print('Merchant: You can choose between', list(merchant_shop.keys())[12], '|', list(merchant_shop.keys())[13], '|', list(merchant_shop.keys())[14])
                    print('Weapon:', list(merchant_shop.keys())[12], '|', 'Price:', merchant_shop['Freezing Bow']['gold'])
                    print('Weapon:', list(merchant_shop.keys())[13], '|', 'Price:', merchant_shop['Cursed Sword']['gold'])
                    print('Weapon:', list(merchant_shop.keys())[14], '|', 'Price:', merchant_shop['Hellfire Lasso']['gold'])
                    print('Your current balance is: {}'.format(chosen_hero['gold']))

                    while True:

                        weapon_chosen = input('I choose: ')

                        if weapon_chosen not in [list(merchant_shop.keys())[12], list(merchant_shop.keys())[13], list(merchant_shop.keys())[14]]:
                            print("Chosen weapon does not exist! Enter the valid weapon name!")
                            continue
                            
                        # FREEZING BOW

                        elif weapon_chosen in [list(merchant_shop.keys())[12], list(merchant_shop.keys())[13], list(merchant_shop.keys())[14]] and weapon_chosen == list(merchant_shop.keys())[12] and chosen_hero['gold'] >= merchant_shop['Freezing Bow']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Freezing Bow']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['weapons'].append(list(merchant_shop.keys())[12])
                            chosen_hero['power'] += merchant_shop['Freezing Bow']['power']

                            break
                            
                        # CURSED SWORD
                            
                        elif weapon_chosen in [list(merchant_shop.keys())[12], list(merchant_shop.keys())[13], list(merchant_shop.keys())[14]] and weapon_chosen == list(merchant_shop.keys())[13] and chosen_hero['gold'] >= merchant_shop['Cursed Sword']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Cursed Sword']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['weapons'].append(list(merchant_shop.keys())[13])
                            chosen_hero['power'] += merchant_shop['Cursed Sword']['power']

                            break
                            
                        # HELLFIRE LASSO
                            
                        elif weapon_chosen in [list(merchant_shop.keys())[12], list(merchant_shop.keys())[13], list(merchant_shop.keys())[14]] and weapon_chosen == list(merchant_shop.keys())[14] and chosen_hero['gold'] >= merchant_shop['Hellfire Lasso']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Hellfire Lasso']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['weapons'].append(list(merchant_shop.keys())[14])
                            chosen_hero['power'] += merchant_shop['Hellfire Lasso']['power']

                            break
                                
                        else:
                            print('You do not have enough money')
                            break
                            
                # MAGE | ARMOUR

                elif hero_class == 'mage' and item == 'armour':

                    print('Merchant: You can choose between', list(merchant_shop.keys())[3], '|', list(merchant_shop.keys())[4], '|', list(merchant_shop.keys())[5])
                    print('Armour:', list(merchant_shop.keys())[3], '|', 'Price:', merchant_shop['Bronze Armour']['gold'])
                    print('Armour:', list(merchant_shop.keys())[4], '|', 'Price:', merchant_shop['Silver Armour']['gold'])
                    print('Armour:', list(merchant_shop.keys())[5], '|', 'Price:', merchant_shop['Platinum Armour']['gold'])
                    print('Your current balance is: {}'.format(chosen_hero['gold']))

                    while True:

                        armour_chosen = input('I choose: ')

                        if armour_chosen not in [list(merchant_shop.keys())[3], list(merchant_shop.keys())[4], list(merchant_shop.keys())[5]]:
                            print("Chosen armour does not exist! Enter the valid armour name!")
                            continue
                            
                        # BRONZE ARMOUR

                        elif armour_chosen in [list(merchant_shop.keys())[3], list(merchant_shop.keys())[4], list(merchant_shop.keys())[5]] and armour_chosen == list(merchant_shop.keys())[3] and chosen_hero['gold'] >= merchant_shop['Bronze Armour']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Bronze Armour']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['armours'].append(list(merchant_shop.keys())[3])
                            chosen_hero['armour'] += merchant_shop['Bronze Armour']['armour']

                            break
                            
                        # SILVER ARMOUR
                            
                        elif armour_chosen in [list(merchant_shop.keys())[3], list(merchant_shop.keys())[4], list(merchant_shop.keys())[5]] and armour_chosen == list(merchant_shop.keys())[4] and chosen_hero['gold'] >= merchant_shop['Silver Armour']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Silver Armour']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['armours'].append(list(merchant_shop.keys())[4])
                            chosen_hero['armour'] += merchant_shop['Silver Armour']['armour']

                            break
                            
                        # PLATINUM ARMOUR
                            
                        elif armour_chosen in [list(merchant_shop.keys())[3], list(merchant_shop.keys())[4], list(merchant_shop.keys())[5]] and armour_chosen == list(merchant_shop.keys())[5] and chosen_hero['gold'] >= merchant_shop['Platinum Armour']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Platinum Armour']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['armours'].append(list(merchant_shop.keys())[5])
                            chosen_hero['armour'] += merchant_shop['Platinum Armour']['armour']

                            break
                                
                        else:
                            print('You do not have enough money')
                            break
                            
                # MAGE | ALLY

                elif hero_class == 'mage' and item == 'ally':

                    print('Merchant: You can choose between', list(merchant_shop.keys())[0], '|', list(merchant_shop.keys())[1], '|', list(merchant_shop.keys())[2])
                    print('Ally:', list(merchant_shop.keys())[0], '|', 'Price:', merchant_shop['Northern Wolf']['gold'])
                    print('Ally:', list(merchant_shop.keys())[1], '|', 'Price:', merchant_shop['One-Armed Dwarf']['gold'])
                    print('Ally:', list(merchant_shop.keys())[2], '|', 'Price:', merchant_shop['Enchanted Elf']['gold'])
                    print('Your current balance is: {}'.format(chosen_hero['gold']))

                    while True:

                        ally_chosen = input('I choose: ')

                        if ally_chosen not in [list(merchant_shop.keys())[0], list(merchant_shop.keys())[1], list(merchant_shop.keys())[2]]:
                            print("Chosen ally does not exist! Enter the valid ally name!")
                            continue
                            
                        # NORTHERN WOLF

                        elif ally_chosen in [list(merchant_shop.keys())[0], list(merchant_shop.keys())[1], list(merchant_shop.keys())[2]] and ally_chosen == list(merchant_shop.keys())[0] and chosen_hero['gold'] >= merchant_shop['Northern Wolf']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Northern Wolf']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['allies'].append(list(merchant_shop.keys())[0])
                            chosen_hero['allies_health'] += merchant_shop['Northern Wolf']['health']
                            chosen_hero['allies_power'] += merchant_shop['Northern Wolf']['power']

                            break
                            
                        # ONE-ARMED DWARF
                            
                        elif ally_chosen in [list(merchant_shop.keys())[0], list(merchant_shop.keys())[1], list(merchant_shop.keys())[2]] and ally_chosen == list(merchant_shop.keys())[1] and chosen_hero['gold'] >= merchant_shop['One-Armed Dwarf']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['One-Armed Dwarf']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['allies'].append(list(merchant_shop.keys())[1])
                            chosen_hero['allies_health'] += merchant_shop['One-Armed Dwarf']['health']
                            chosen_hero['allies_power'] += merchant_shop['One-Armed Dwarf']['power']

                            break
                            
                        # ENCHANTED ELF
                            
                        elif ally_chosen in [list(merchant_shop.keys())[0], list(merchant_shop.keys())[1], list(merchant_shop.keys())[2]] and ally_chosen == list(merchant_shop.keys())[2] and chosen_hero['gold'] >= merchant_shop['Enchanted Elf']['gold']:

                            print('Merchant: Nice choice!')

                            chosen_hero['gold'] -= merchant_shop['Enchanted Elf']['gold']

                            print('Your current balance is {}'.format(chosen_hero['gold']))

                            chosen_hero['allies'].append(list(merchant_shop.keys())[2])
                            chosen_hero['allies_health'] += merchant_shop['Enchanted Elf']['health']
                            chosen_hero['allies_power'] += merchant_shop['Enchanted Elf']['power']

                            break
                                
                        else:
                            print('You do not have enough money')
                            break
                                
            elif exit.lower() == "no":
                    
                break

# RIDDLES 

import random

def Dices_Riddle():
    
    print("We will throw dices 3 times, who will get more points summed – winner")

    sum_a = 0
    sum_b = 0

    for _ in range(3):

        a = random.randint(1, 6)
        b = random.randint(1, 6)
        print('Throw dices, you got:', a)
        print('My turn! I got:', b)
        sum_a += a
        sum_b += b

    if sum_a > sum_b:
        print('Final score: ', sum_a, '>', sum_b)
        print('So you win! Lucky...')
        chosen_hero['gold'] += 500
        print('Take your 500 gold, spend it wisely!')
    elif sum_a == sum_b:
        print('Final score: ', sum_a, '=', sum_b,)
        print('Draw... However I have no more time, I let you win lucky stranger')
        chosen_hero['gold'] += 500
        print('Take your 500 gold, spend it wisely!')
    else:
        print('Final score: ', sum_a, '<', sum_b)
        print('So I won, HAHAHA')
        chosen_hero['health'] -= 50
        print('I take 50 health points from you, consider it my mercy, fool')
    
    
text_riddles_bank = ['I follow you all the time and copy your every move, but you can’t touch me or catch me. What am I?', 
                    'If you’ve got me, you want to share me; if you share me, you haven’t kept me. What am I?',
                    'It belongs to you, but other people use it more than you do. What is it?',
                    'What can you break, even if you never pick it up or touch it?',
                    'I am an odd number. Take away a letter and I become even. What number am I?']

def Text_Riddle():
    
    print("Guess the right answer, you'll have 3 chances")
    a = random.choice(text_riddles_bank)
    print('RIDDLE:', a)
    
    i = 0
    
    if a == text_riddles_bank[0]:
        while i != 3:
            guess = input("My guess is: ")
            if guess.lower() == 'shadow':
                chosen_hero['gold'] += 500
                print('Take your 500 gold, spend it wisely!')
                break
            else: 
                i += 1
                continue
               
            
    elif a == text_riddles_bank[1]:
         while i != 3:
            guess = input("My guess is: ")
            if guess.lower() == 'secret':
                chosen_hero['gold'] += 500
                print('Take your 500 gold, spend it wisely!')
                break
            else: 
                i += 1
                continue
                
    
    elif a == text_riddles_bank[2]:
         while i != 3:
            guess = input("My guess is: ")
            if guess.lower() == 'name':
                chosen_hero['gold'] += 500
                print('Take your 500 gold, spend it wisely!')
                break
            else: 
                i += 1
                continue
                
    elif a == text_riddles_bank[3]:
         while i != 3:
            guess = input("My guess is: ")
            if guess.lower() == 'promise':
                chosen_hero['gold'] += 500
                print('Take your 500 gold, spend it wisely!')
                break
            else: 
                i += 1
                continue
                
    elif a == text_riddles_bank[4]:
         while i != 3:
            guess = input("My guess is: ")
            if guess.lower() == 'seven' or '7':
                chosen_hero['gold'] += 500
                print('Take your 500 gold, spend it wisely!')
                break
            else: 
                i += 1
                continue
                
    if i > 3:
        chosen_hero['health'] -= 50
        print('I take 50 health points from you, consider it my mercy, fool')
        
    

rps = ['rock', 'paper', 'scissors']

def RockPaperScissors_Riddle():
    
    while True:
        a = input('Choose rock, paper or scissors and enter your choice: ')
        if a in rps:
            break
        else:
            continue
    b = random.choice(rps)
    
    print(a)
    print(b)
    
    if a == 'scissors' and b == 'scissors':
        chosen_hero['gold'] += 500
        print('Draw! But, you look so weak... Take your 500 gold, spend it wisely!')
    elif a == 'rock' and b == 'rock':
        chosen_hero['gold'] += 500
        print('Draw! But, you look so weak... Take your 500 gold, spend it wisely!')
    elif a == 'paper' and b == 'paper':
        chosen_hero['gold'] += 500
        print('Draw! But, you look so weak... Take your 500 gold, spend it wisely!')
    elif a == 'scissors' and b == 'paper':
        chosen_hero['gold'] += 500
        print('You won! Take your 500 gold, spend it wisely!')
    elif a == 'paper' and b == 'rock':
        chosen_hero['gold'] += 500
        print('You won! Take your 500 gold, spend it wisely!')
    elif a == 'rock' and b == 'scissors':
        chosen_hero['gold'] += 500
        print('You won! Take your 500 gold, spend it wisely!')
    elif b == 'scissors' and a == 'paper':
        chosen_hero['health'] -= 50
        print('I take 50 health points from you, consider it my mercy, fool')
    elif b == 'paper' and a == 'rock':
        chosen_hero['health'] -= 50
        print('I take 50 health points from you, consider it my mercy, fool')
    elif b == 'rock' and a == 'scissors':
        chosen_hero['health'] -= 50
        print('I take 50 health points from you, consider it my mercy, fool')


riddles_functions = [Dices_Riddle, Text_Riddle, RockPaperScissors_Riddle]

def Riddle():

    riddle_agree = input('''During further exploring you've encountered strange man...
    Riddler: Do you want to play with me? 
    If you win, you will get great prizes, but if you loose... you'll see
    So if you want to play – enter yes, otherwise enter no: ''')
    
    while True:

        if riddle_agree.lower() != "yes":
            riddle_agree_check = input("Strange asnwer... Are you sure you don't want to play?: ")
            if riddle_agree_check.lower() == 'yes':
                break
            else:
                print("LET'S PLAY")
                random.choice(riddles_functions)()
                break
                
            
        
        else:
            print("LET'S PLAY")
            random.choice(riddles_functions)()
            break
            
# BOSS STATS

def boss_stats(boss):
    damage = boss['power']
    health = boss['health'] + boss['armour']
    return damage, health

# FIGHT WITH BOSS SIMULATION

def Fight_Boss():
    
    global boss_counter
    
    print("You've encountered Boss! Be brave and show them what you are made of!")
        
    if chosen_world == MAGIC_VALLEY_WORLD:
             
        current_boss = bosses['Arcane Overlord']
        boss_damage, boss_health = boss_stats(current_boss)

        player_damage, player_health = hero_stats(hero_class)
        allies_damage, allies_health = allies_stats(hero_class)
        total_damage = player_damage + allies_damage
            
        
        while True:

            # player always attacks first
            
            if player_health > 0 and boss_health <= 0:
                print('CONGRATULATIONS, YOU WON BOSS BATTLE!')
                print('YOU EARNED {}'.format(bosses['Arcane Overlord']['gold_prize']), 'gold')
                chosen_hero['gold'] += bosses['Arcane Overlord']['gold_prize']
                boss_counter += 1
                break
            
            elif player_health <= 0 and boss_health > 0:
                print('YOU ARE DEAD')
                break
            
            boss_health -= total_damage
            print("{} dealed".format(hero_name), player_damage, "damage to Arcane Overlord")
            print("Arcane Overlord health is: ", boss_health)
            
            player_health -= boss_damage
            print("Arcane Overlord dealed", boss_damage, "damage to {}".format(hero_name))
            print("{} health is: ".format(hero_name), player_health)
            
            if chosen_hero['allies']:
            
                allies_health -= boss_damage
                print("Arcane Overlord dealed", boss_damage, "damage to {}".format(chosen_hero['allies']))
                print("{} health is: ".format(chosen_hero['allies']), allies_health)
            
            
  
            
    elif chosen_world == MIRROR_MAZE_WORLD:
        
        current_boss = bosses['Reflection Master']
        boss_damage, boss_health = boss_stats(current_boss)

        player_damage, player_health = hero_stats(hero_class)
        allies_damage, allies_health = allies_stats(hero_class)
        total_damage = player_damage + allies_damage
            
        
        while True:

            # player always attacks first
            
            if player_health > 0 and boss_health <= 0:
                print('CONGRATULATIONS, YOU WON BOSS BATTLE!')
                print('YOU EARNED {}'.format(bosses['Reflection Master']['gold_prize']), 'gold')
                chosen_hero['gold'] += bosses['Reflection Master']['gold_prize']
                boss_counter += 1
                break
            
            elif player_health <= 0 and boss_health > 0:
                print('YOU ARE DEAD')
                break
            
            boss_health -= total_damage
            print("{} dealed".format(hero_name), total_damage, "damage to Reflection Master")
            print("Reflection Master health is: ", boss_health)
            
            player_health -= boss_damage
            print("Reflection Master dealed", boss_damage, "damage to {}".format(hero_name))
            print("{} health is: ".format(hero_name), player_health)
            
            if chosen_hero['allies']:
            
                allies_health -= boss_damage
                print("Reflection Master dealed", boss_damage, "damage to {}".format(chosen_hero['allies']))
                print("{} health is: ".format(chosen_hero['allies']), allies_health)
    
    elif chosen_world == TOWER_OF_ILLUSIONS_WORLD:
        
        current_boss = bosses['Spectral Conjurer']
        boss_damage, boss_health = boss_stats(current_boss)

        player_damage, player_health = hero_stats(hero_class)
        allies_damage, allies_health = allies_stats(hero_class)
        total_damage = player_damage + allies_damage
            
        
        while True:

            # player always attacks first
            
            if player_health > 0 and boss_health <= 0:
                print('CONGRATULATIONS, YOU WON BOSS BATTLE!')
                print('YOU EARNED {}'.format(bosses['Spectral Conjurer']['gold_prize']), 'gold')
                chosen_hero['gold'] += bosses['Spectral Conjurer']['gold_prize']
                boss_counter += 1
                break
            
            elif player_health <= 0 and boss_health > 0:
                print('YOU ARE DEAD')
                break
            
            boss_health -= total_damage
            print("{} dealed".format(hero_name), player_damage, "damage to Spectral Conjurer")
            print("Spectral Conjurer health is: ", boss_health)
            
            player_health -= boss_damage
            print("Spectral Conjurer dealed", boss_damage, "damage to {}".format(hero_name))
            print("{} health is: ".format(hero_name), player_health)
            
            if chosen_hero['allies']:
            
                allies_health -= boss_damage
                print("Spectral Conjurer dealed", boss_damage, "damage to {}".format(chosen_hero['allies']))
                print("{} health is: ".format(chosen_hero['allies']), allies_health)


# FINAL GAME SCENARIO
    
boss_counter = 0

# TO WIN YOU NEED TO DEFEAT ALL 3 BOSSES

while boss_counter != 3:
    
    Create_Hero_1()
    Create_Hero_2()
    print('Stats of your hero {}:'.format(hero_name), Hero_Stats())
    Choose_World()
    Fight_Monster()
    print('Stats of your hero {}:'.format(hero_name), Hero_Stats())
    exit = ''
    Merchant_Shopping()
    Riddle()
    print('Stats of your hero {}:'.format(hero_name), Hero_Stats())
    exit = ''
    Merchant_Shopping()
    Fight_Boss()
    print('Stats of your hero {}:'.format(hero_name), Hero_Stats())
    exit = ''
    Merchant_Shopping()
    
    Choose_World()
    Fight_Monster()
    print('Stats of your hero {}:'.format(hero_name), Hero_Stats())
    exit = ''
    Merchant_Shopping()
    Riddle()
    print('Stats of your hero {}:'.format(hero_name), Hero_Stats())    
    exit = ''
    Merchant_Shopping()
    Fight_Boss()
    print('Stats of your hero {}:'.format(hero_name), Hero_Stats())
    exit = ''
    Merchant_Shopping()

    Choose_World()
    Fight_Monster()
    print('Stats of your hero {}:'.format(hero_name), Hero_Stats())
    exit = ''
    Merchant_Shopping()
    Riddle()
    print('Stats of your hero {}:'.format(hero_name), Hero_Stats())
    exit = ''
    Merchant_Shopping()
    Fight_Boss()

print("YOU ARE THE CHAMPION, MY FRIEND! THANK YOU FOR PLAYING! I HOPE IT WAS PLEASANT EXPERIENCE! <3")
